# %% [markdown]
# <a href="https://colab.research.google.com/github/lrrong2020/A/blob/main/FYP_crash1_NewAug_Overfit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Prep

# %%
# !cp /content/gdrive/MyDrive/Kaggle/unzip/data.zip /home

# %%
# %cd /home
# !unzip -nq /home/data.zip "train/*"
# Out:
# /home

# %%
# !rm /home/data.zip

# %% [markdown]
# #GitHub

# %%
import pandas as pd #For reading csv files.
import numpy as np
import os
import matplotlib.pyplot as plt #For plotting.
import PIL.Image as Image #For working with image files.

#Importing torch
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset,DataLoader #For working with data.
from torchvision import models,transforms #For pretrained models,image transformations.
from torch.optim.lr_scheduler import StepLR

#manual seed for reproductivity and potential performance improvement
torch.manual_seed(3407)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') #Use GPU if it's available or else use CPU.
print(device) #Prints the device we're using.
# Out:
# cuda

# %%
# !cp /content/gdrive/MyDrive/Kaggle/unzip/allLabels.csv /home

# %%
path = "/home/"

#label csv
all_df = pd.read_csv(f"{path}allLabels.csv")

from sklearn.model_selection import train_test_split
# subset for hyperparameters tuning

part = 0.80
train_df, drop_df = train_test_split(all_df, test_size=part, random_state=42)
test_sample_size = round(7000 * (1 - part) )  #roughtly 1/3
train_df, test_df = train_test_split(train_df, test_size=test_sample_size, random_state=42)

# Assuming train_df is your original training DataFrame
# test_sample_size = 7000 # roughtly 1/3
# train_df, test_df = train_test_split(all_df, test_size=test_sample_size, random_state=42)

# Now split the remaining training data into training and validation sets
train_df, valid_df = train_test_split(train_df, test_size=0.1, random_state=42)

print(f'No.of.training_samples: {len(train_df)}')
print(f'No.of.testing_samples: {len(test_df)}')
print(f'No.of.val_samples: {len(valid_df)}')
# Out:
# No.of.training_samples: 5062
# No.of.testing_samples: 1400
# No.of.val_samples: 563

# %%
#Histogram of label counts.
train_df.level.hist()
plt.xticks([0,1,2,3,4])
plt.grid(False)
plt.show()

# %%
class_counts = train_df['level'].value_counts().to_dict()
print(class_counts)
# Out:
# {0: 3691, 2: 777, 1: 340, 3: 146, 4: 108}

# %%
majority_class_count = max(class_counts.values())
print(majority_class_count)
# Out:
# 3691

# %%
#As you can see,the data is imbalanced.
#So we've to calculate weights for each class,which can be used in calculating loss.

from sklearn.utils import class_weight #For calculating weights for each class.
class_weights = class_weight.compute_class_weight(class_weight='balanced',classes=np.array([0,1,2,3,4]),y=train_df['level'].values)
class_weights = torch.tensor(class_weights,dtype=torch.float).to(device)

print(class_weights) #Prints the calculated weights for the classes.
# Out:
# tensor([0.2743, 2.9776, 1.3030, 6.9342, 9.3741], device='cuda:0')

# %%
from torchvision.transforms import functional as F
import random

class Augmenter:
    def __init__(self, rotate=True, flip_lr=True, flip_tb=True):
        self.rotate = rotate
        self.flip_lr = flip_lr
        self.flip_tb = flip_tb

    def __call__(self, img):
        if self.rotate:
            img = img.rotate(random.uniform(-25, 25))
        if self.flip_lr and random.random() > 0.5:
            img = F.hflip(img)
        if self.flip_tb and random.random() > 0.5:
            img = F.vflip(img)
        return img

augmenter = Augmenter()

# %%
from torchvision.transforms import functional as F
from PIL import Image
import random
import numpy as np

class AugmenterAGG:
    def __init__(self, rotate=True, flip_lr=True, flip_tb=True, translate=True):
        self.rotate = rotate
        self.flip_lr = flip_lr
        self.flip_tb = flip_tb
        self.translate = translate

    def __call__(self, img):
        if self.rotate:
            img = img.rotate(random.uniform(0, 90))
        if self.flip_lr and random.random() > 0.5:
            img = F.hflip(img)
        if self.flip_tb and random.random() > 0.5:
            img = F.vflip(img)
        if self.translate:
            img = F.affine(img, 0, (random.randint(-30, 30), random.randint(-30, 30)), 1, 0)
        return img

augmenter_agg = AugmenterAGG()

# %%
#For getting a random image from our training set.
# num = int(np.random.randint(0,len(train_df)-1,(1,))) #Picks a random number.
# sample_image = (f'{path}train/{train_df["image"][num]}.jpeg')#Image file.
# sample_image = Image.open(sample_image)
# plt.imshow(sample_image)
# plt.axis('off')
# plt.title(f'Class: {train_df["level"][num]}') #Class of the random image.
# plt.show()

# %%
class dataset(Dataset):
    def __init__(self,df,data_path,image_transform=None,augment_transform=None,augment_transform_agg=None,train=True):
        super(Dataset,self).__init__()
        self.df = df
        self.data_path = data_path
        self.image_transform = image_transform
        self.augment_transform = augment_transform
        self.augment_transform_agg = augment_transform_agg
        self.train = train
        self.minority_classes = [1, 2, 3, 4]  # specify minority classes

    def __len__(self):
        return len(self.df)

    def __getitem__(self,index):
        image_id = self.df['image'][index]
        image = Image.open(f'{self.data_path}/{image_id}.jpeg')
        label = self.df['level'][index] if self.train else None

        if self.train and self.augment_transform and label == 2:
            image = self.augment_transform_agg(image)
        if self.train and self.augment_transform and label in self.minority_classes:
            image = self.augment_transform(image)

        if self.image_transform:
            image = self.image_transform(image)

        return (image, label) if self.train else image

# %%
image_transform = transforms.Compose([
    transforms.Resize([512,512]),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

train_df = train_df.reset_index(drop=True)
valid_df = valid_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# Create the datasets
train_set = dataset(train_df, f'{path}train', image_transform=image_transform, augment_transform=augmenter, augment_transform_agg=augmenter_agg)
test_set = dataset(test_df, f'{path}train', image_transform=image_transform)
valid_set = dataset(valid_df, f'{path}train', image_transform=image_transform)

# %%
train_dataloader = DataLoader(train_set,batch_size=16,shuffle=True, num_workers=0)
valid_dataloader = DataLoader(valid_set,batch_size=16,shuffle=False, num_workers=0)
test_dataloader = DataLoader(test_set, batch_size=16, shuffle=False, num_workers=0)

# %%
from torchvision.models import resnet50,ResNet50_Weights

model = models.resnet50(weights=ResNet50_Weights.DEFAULT) #Downloads the resnet50 model which is pretrained on Imagenet dataset.
# Replace the Final layer of pretrained resnet50
model.fc = nn.Sequential(
    nn.Linear(2048, 5),
)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 201MB/s]

# %%
model = model.to(device) #Moves the model to the device.

# %%
def train(dataloader,model,loss_fn,optimizer):
    '''
    train function updates the weights of the model based on the
    loss using the optimizer in order to get a lower loss.

    Args :
         dataloader: Iterator for the batches in the data_set.
         model: Given an input produces an output by multiplying the input with the model weights.
         loss_fn: Calculates the discrepancy between the label & the model's predictions.
         optimizer: Updates the model weights.

    Returns :
         Average loss per batch which is calculated by dividing the losses for all the batches
         with the number of batches.
    '''

    model.train() #Sets the model for training.

    total = 0
    correct = 0
    running_loss = 0

    for batch,(x,y) in enumerate(dataloader): #Iterates through the batches.


        output = model(x.to(device)) #model's predictions.
        loss   = loss_fn(output,y.to(device)) #loss calculation.

        running_loss += loss.item()

        total        += y.size(0)
        predictions   = output.argmax(dim=1).cpu().detach() #Index for the highest score for all the samples in the batch.
        correct      += (predictions == y.cpu().detach()).sum().item() #No.of.cases where model's predictions are equal to the label.
        accuracy = 100*(correct/total)

        optimizer.zero_grad() #Gradient values are set to zero.
        loss.backward() #Calculates the gradients.
        optimizer.step() #Updates the model weights.

        #for memory
        torch.cuda.empty_cache()

        # Print some information every 100 batches
        if batch % 70 == 0:
            print(f'Batch {batch}/{len(dataloader)} processed, running loss: {running_loss:.6f}, correct predictions: {correct}, total: {total}')


    avg_loss = running_loss/len(dataloader) # Average loss for a single batch

    print(f'\nTraining Loss per batch = {avg_loss:.6f}',end='\t')
    print(f'Accuracy on Training set = {100*(correct/total):.6f}% [{correct}/{total}]') #Prints the Accuracy.

    torch.save(model, '/content/gdrive/MyDrive/Kaggle/unzip/DR_new_aug_4.pt')
    return avg_loss, accuracy

# %%
def validate(dataloader,model,loss_fn):
    '''
    validate function calculates the average loss per batch and the accuracy of the model's predictions.

    Args :
         dataloader: Iterator for the batches in the data_set.
         model: Given an input produces an output by multiplying the input with the model weights.
         loss_fn: Calculates the discrepancy between the label & the model's predictions.

    Returns :
         Average loss per batch which is calculated by dividing the losses for all the batches
         with the number of batches.
    '''

    model.eval() #Sets the model for evaluation.

    total = 0
    correct = 0
    running_loss = 0

    with torch.no_grad(): #No need to calculate the gradients.

        for x,y in dataloader:

            output        = model(x.to(device)) #model's output.
            loss          = loss_fn(output,y.to(device)).item() #loss calculation.
            running_loss += loss

            total        += y.size(0)
            predictions   = output.argmax(dim=1).cpu().detach()
            correct      += (predictions == y.cpu().detach()).sum().item()
            accuracy = 100*(correct/total)

    avg_loss = running_loss/len(dataloader) #Average loss per batch.

    print(f'\nValidation Loss per batch = {avg_loss:.6f}',end='\t')
    print(f'Accuracy on Validation set = {100*(correct/total):.6f}% [{correct}/{total}]') #Prints the Accuracy.

    return avg_loss, accuracy

# %%
import matplotlib.pyplot as plt

def plot_learning_curve(train_losses, valid_losses, train_accuracies, valid_accuracies):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, 'g', label='Training Loss')
    plt.plot(epochs, valid_losses, 'b', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, 'g', label='Training Accuracy')
    plt.plot(epochs, valid_accuracies, 'b', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
def optimize(train_dataloader,valid_dataloader,model,loss_fn,optimizer,nb_epochs, patience):
    '''
    optimize function calls the train & validate functions for (nb_epochs) times.

    Args :
        train_dataloader: DataLoader for the train_set.
        valid_dataloader: DataLoader for the valid_set.
        model: Given an input produces an output by multiplying the input with the model weights.
        loss_fn: Calculates the discrepancy between the label & the model's predictions.
        optimizer: Updates the model weights.
        nb_epochs: Number of epochs.

    Returns :
        Tuple of lists containing losses for all the epochs.
    '''
    # Initialize the learning rate scheduler
    # scheduler = StepLR(optimizer, step_size=4, gamma=0.5)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)


    #Lists to store losses for all the epochs.
    train_losses = []
    valid_losses = []
    train_accuracies = []
    valid_accuracies = []

    df = pd.DataFrame(columns=['epoch', 'train_loss', 'train_accuracy', 'valid_loss', 'valid_accuracy'])

    best_valid_loss = float('inf')
    no_improve_epoch = 0

    for epoch in range(nb_epochs):
        print(f'\nEpoch {epoch+1}/{nb_epochs}')
        print('-------------------------------')
        print("Epoch: %d, Learning Rate: %f " % (epoch, optimizer.param_groups[0]['lr']))
        train_loss, train_accuracy = train(train_dataloader,model,loss_fn,optimizer)
        valid_loss, valid_accuracy = validate(valid_dataloader,model,loss_fn)

        train_losses.append(train_loss)
        valid_losses.append(valid_loss)
        train_accuracies.append(train_accuracy)
        valid_accuracies.append(valid_accuracy)

        print(f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')
        print(f'Valid Loss: {valid_loss:.4f}, Valid Accuracy: {valid_accuracy:.4f}')

        plot_learning_curve(train_losses, valid_losses, train_accuracies, valid_accuracies)


        # Check if the validation loss improved
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            no_improve_epoch = 0

            # Save the model when validation loss improves
            torch.save(model.state_dict(), 'best_model.pt')
        else:
            no_improve_epoch += 1

        # If the validation loss did not improve for 'patience' epochs, stop training
        if no_improve_epoch >= patience:
            print(f'Early stopping at epoch {epoch+1}, the validation loss did not improve for the last {patience} epochs')

            # Save to CSV
            df.to_csv('training_validation_metrics.csv', index=False)
            break

        # Step the learning rate scheduler
        # scheduler.step()
        scheduler.step(valid_loss)

        df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)

    print('\nTraining has completed!')

    # Save to CSV
    df.to_csv('training_validation_metrics.csv', index=False)

    return train_losses,valid_losses

# %%
loss_fn   = nn.CrossEntropyLoss(weight=class_weights) #CrossEntropyLoss with class_weights.
optimizer = torch.optim.SGD(model.parameters(),lr=0.005, weight_decay=1e-5)
nb_epochs = 50
patience = 35

#Call the optimize function.
train_losses, valid_losses = optimize(train_dataloader,valid_dataloader,model,loss_fn,optimizer,nb_epochs, patience)
# Out:
# Epoch 1/50
# -------------------------------
# Epoch: 0, Learning Rate: 0.005000
# Batch 0/317 processed, running loss: 1.691782, correct predictions: 1, total: 16
# Batch 70/317 processed, running loss: 113.256161, correct predictions: 374, total: 1136
# Batch 140/317 processed, running loss: 221.255294, correct predictions: 1071, total: 2256
# Batch 210/317 processed, running loss: 328.943115, correct predictions: 1860, total: 3376
# Batch 280/317 processed, running loss: 432.503181, correct predictions: 2631, total: 4496
#
# Training Loss per batch = 1.527401	Accuracy on Training set = 59.304623% [3002/5062]
#
# Validation Loss per batch = 1.484438	Accuracy on Validation set = 69.982238% [394/563]
# Train Loss: 1.5274, Train Accuracy: 59.3046
# Valid Loss: 1.4844, Valid Accuracy: 69.9822
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 2/50
# -------------------------------
# Epoch: 1, Learning Rate: 0.005000
# Batch 0/317 processed, running loss: 1.439098, correct predictions: 13, total: 16
# Batch 70/317 processed, running loss: 95.552181, correct predictions: 843, total: 1136
# Batch 140/317 processed, running loss: 183.614956, correct predictions: 1715, total: 2256
# Batch 210/317 processed, running loss: 267.340652, correct predictions: 2575, total: 3376
# Batch 280/317 processed, running loss: 344.554449, correct predictions: 3489, total: 4496
#
# Training Loss per batch = 1.207832	Accuracy on Training set = 77.578032% [3927/5062]
#
# Validation Loss per batch = 1.426561	Accuracy on Validation set = 71.047957% [400/563]
# Train Loss: 1.2078, Train Accuracy: 77.5780
# Valid Loss: 1.4266, Valid Accuracy: 71.0480
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 3/50
# -------------------------------
# Epoch: 2, Learning Rate: 0.005000
# Batch 0/317 processed, running loss: 0.665608, correct predictions: 15, total: 16
# Batch 70/317 processed, running loss: 64.847451, correct predictions: 965, total: 1136
# Batch 140/317 processed, running loss: 125.659595, correct predictions: 1921, total: 2256
# Batch 210/317 processed, running loss: 187.880774, correct predictions: 2911, total: 3376
# Batch 280/317 processed, running loss: 247.642029, correct predictions: 3902, total: 4496
#
# Training Loss per batch = 0.862371	Accuracy on Training set = 86.941920% [4401/5062]
#
# Validation Loss per batch = 2.034702	Accuracy on Validation set = 75.133215% [423/563]
# Train Loss: 0.8624, Train Accuracy: 86.9419
# Valid Loss: 2.0347, Valid Accuracy: 75.1332
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 4/50
# -------------------------------
# Epoch: 3, Learning Rate: 0.005000
# Batch 0/317 processed, running loss: 0.497771, correct predictions: 15, total: 16
# Batch 70/317 processed, running loss: 53.217167, correct predictions: 1025, total: 1136
# Batch 140/317 processed, running loss: 106.648287, correct predictions: 2028, total: 2256
# Batch 210/317 processed, running loss: 153.659615, correct predictions: 3043, total: 3376
# Batch 280/317 processed, running loss: 197.577307, correct predictions: 4052, total: 4496
#
# Training Loss per batch = 0.691955	Accuracy on Training set = 90.339787% [4573/5062]
#
# Validation Loss per batch = 2.690060	Accuracy on Validation set = 75.666075% [426/563]
# Train Loss: 0.6920, Train Accuracy: 90.3398
# Valid Loss: 2.6901, Valid Accuracy: 75.6661
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 5/50
# -------------------------------
# Epoch: 4, Learning Rate: 0.005000
# Batch 0/317 processed, running loss: 0.379683, correct predictions: 15, total: 16
# Batch 70/317 processed, running loss: 42.883283, correct predictions: 1039, total: 1136
# Batch 140/317 processed, running loss: 85.914753, correct predictions: 2066, total: 2256
# Batch 210/317 processed, running loss: 127.529415, correct predictions: 3094, total: 3376
# Batch 280/317 processed, running loss: 171.068068, correct predictions: 4125, total: 4496
#
# Training Loss per batch = 0.602516	Accuracy on Training set = 91.880680% [4651/5062]
#
# Validation Loss per batch = 2.998243	Accuracy on Validation set = 75.843694% [427/563]
# Train Loss: 0.6025, Train Accuracy: 91.8807
# Valid Loss: 2.9982, Valid Accuracy: 75.8437
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 6/50
# -------------------------------
# Epoch: 5, Learning Rate: 0.005000
# Batch 0/317 processed, running loss: 0.702638, correct predictions: 12, total: 16
# Batch 70/317 processed, running loss: 41.553623, correct predictions: 1046, total: 1136
# Batch 140/317 processed, running loss: 81.288619, correct predictions: 2072, total: 2256
# Batch 210/317 processed, running loss: 116.521169, correct predictions: 3118, total: 3376
# Batch 280/317 processed, running loss: 156.609755, correct predictions: 4149, total: 4496
#
# Training Loss per batch = 0.562607	Accuracy on Training set = 92.335045% [4674/5062]
#
# Validation Loss per batch = 2.855781	Accuracy on Validation set = 75.488455% [425/563]
# Train Loss: 0.5626, Train Accuracy: 92.3350
# Valid Loss: 2.8558, Valid Accuracy: 75.4885
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 7/50
# -------------------------------
# Epoch: 6, Learning Rate: 0.000500
# Batch 0/317 processed, running loss: 0.193838, correct predictions: 16, total: 16
# Batch 70/317 processed, running loss: 30.674407, correct predictions: 1083, total: 1136
# Batch 140/317 processed, running loss: 65.334335, correct predictions: 2128, total: 2256
# Batch 210/317 processed, running loss: 100.026945, correct predictions: 3188, total: 3376
# Batch 280/317 processed, running loss: 131.860931, correct predictions: 4247, total: 4496
#
# Training Loss per batch = 0.469180	Accuracy on Training set = 94.488345% [4783/5062]
#
# Validation Loss per batch = 3.020231	Accuracy on Validation set = 75.666075% [426/563]
# Train Loss: 0.4692, Train Accuracy: 94.4883
# Valid Loss: 3.0202, Valid Accuracy: 75.6661
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 8/50
# -------------------------------
# Epoch: 7, Learning Rate: 0.000500
# Batch 0/317 processed, running loss: 0.378744, correct predictions: 15, total: 16
# Batch 70/317 processed, running loss: 30.160739, correct predictions: 1080, total: 1136
# Batch 140/317 processed, running loss: 61.303746, correct predictions: 2138, total: 2256
# Batch 210/317 processed, running loss: 94.422320, correct predictions: 3189, total: 3376
# Batch 280/317 processed, running loss: 124.141202, correct predictions: 4261, total: 4496
#
# Training Loss per batch = 0.433748	Accuracy on Training set = 94.725405% [4795/5062]
#
# Validation Loss per batch = 3.031121	Accuracy on Validation set = 75.666075% [426/563]
# Train Loss: 0.4337, Train Accuracy: 94.7254
# Valid Loss: 3.0311, Valid Accuracy: 75.6661
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 9/50
# -------------------------------
# Epoch: 8, Learning Rate: 0.000500
# Batch 0/317 processed, running loss: 0.367009, correct predictions: 15, total: 16
# Batch 70/317 processed, running loss: 32.300625, correct predictions: 1069, total: 1136
# Batch 140/317 processed, running loss: 64.925910, correct predictions: 2132, total: 2256
# Batch 210/317 processed, running loss: 91.983843, correct predictions: 3201, total: 3376
# Batch 280/317 processed, running loss: 119.266778, correct predictions: 4268, total: 4496
#
# Training Loss per batch = 0.426253	Accuracy on Training set = 94.962465% [4807/5062]
#
# Validation Loss per batch = 2.910895	Accuracy on Validation set = 75.488455% [425/563]
# Train Loss: 0.4263, Train Accuracy: 94.9625
# Valid Loss: 2.9109, Valid Accuracy: 75.4885
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 10/50
# -------------------------------
# Epoch: 9, Learning Rate: 0.000500
# Batch 0/317 processed, running loss: 1.367767, correct predictions: 14, total: 16
# Batch 70/317 processed, running loss: 32.196731, correct predictions: 1073, total: 1136
# Batch 140/317 processed, running loss: 61.426573, correct predictions: 2130, total: 2256
# Batch 210/317 processed, running loss: 89.580287, correct predictions: 3200, total: 3376
# Batch 280/317 processed, running loss: 116.662314, correct predictions: 4269, total: 4496
#
# Training Loss per batch = 0.425027	Accuracy on Training set = 94.824180% [4800/5062]
#
# Validation Loss per batch = 3.144331	Accuracy on Validation set = 75.666075% [426/563]
# Train Loss: 0.4250, Train Accuracy: 94.8242
# Valid Loss: 3.1443, Valid Accuracy: 75.6661
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 11/50
# -------------------------------
# Epoch: 10, Learning Rate: 0.000050
# Batch 0/317 processed, running loss: 0.617715, correct predictions: 14, total: 16
# Batch 70/317 processed, running loss: 29.631216, correct predictions: 1077, total: 1136
# Batch 140/317 processed, running loss: 60.969412, correct predictions: 2139, total: 2256
# Batch 210/317 processed, running loss: 90.485375, correct predictions: 3197, total: 3376
# Batch 280/317 processed, running loss: 117.109212, correct predictions: 4268, total: 4496
#
# Training Loss per batch = 0.410666	Accuracy on Training set = 94.922955% [4805/5062]
#
# Validation Loss per batch = 3.430440	Accuracy on Validation set = 75.666075% [426/563]
# Train Loss: 0.4107, Train Accuracy: 94.9230
# Valid Loss: 3.4304, Valid Accuracy: 75.6661
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 12/50
# -------------------------------
# Epoch: 11, Learning Rate: 0.000050
# Batch 0/317 processed, running loss: 0.705026, correct predictions: 12, total: 16
# Batch 70/317 processed, running loss: 27.853999, correct predictions: 1078, total: 1136
# Batch 140/317 processed, running loss: 56.582343, correct predictions: 2132, total: 2256
# Batch 210/317 processed, running loss: 84.552720, correct predictions: 3197, total: 3376
# Batch 280/317 processed, running loss: 112.650052, correct predictions: 4263, total: 4496
#
# Training Loss per batch = 0.405441	Accuracy on Training set = 94.725405% [4795/5062]
#
# Validation Loss per batch = 3.187400	Accuracy on Validation set = 75.666075% [426/563]
# Train Loss: 0.4054, Train Accuracy: 94.7254
# Valid Loss: 3.1874, Valid Accuracy: 75.6661
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 13/50
# -------------------------------
# Epoch: 12, Learning Rate: 0.000050
# Batch 0/317 processed, running loss: 0.088783, correct predictions: 15, total: 16
# Batch 70/317 processed, running loss: 28.066759, correct predictions: 1075, total: 1136
# Batch 140/317 processed, running loss: 54.860446, correct predictions: 2152, total: 2256
# Batch 210/317 processed, running loss: 87.317817, correct predictions: 3213, total: 3376
# Batch 280/317 processed, running loss: 113.717711, correct predictions: 4279, total: 4496
#
# Training Loss per batch = 0.405598	Accuracy on Training set = 95.140261% [4816/5062]
#
# Validation Loss per batch = 3.316488	Accuracy on Validation set = 75.488455% [425/563]
# Train Loss: 0.4056, Train Accuracy: 95.1403
# Valid Loss: 3.3165, Valid Accuracy: 75.4885
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 14/50
# -------------------------------
# Epoch: 13, Learning Rate: 0.000050
# Batch 0/317 processed, running loss: 0.702441, correct predictions: 15, total: 16
# Batch 70/317 processed, running loss: 31.147826, correct predictions: 1071, total: 1136
# Batch 140/317 processed, running loss: 58.072316, correct predictions: 2147, total: 2256
# Batch 210/317 processed, running loss: 84.340924, correct predictions: 3224, total: 3376
# Batch 280/317 processed, running loss: 110.582999, correct predictions: 4290, total: 4496
#
# Training Loss per batch = 0.405695	Accuracy on Training set = 95.179771% [4818/5062]
#
# Validation Loss per batch = 3.246469	Accuracy on Validation set = 75.488455% [425/563]
# Train Loss: 0.4057, Train Accuracy: 95.1798
# Valid Loss: 3.2465, Valid Accuracy: 75.4885
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 15/50
# -------------------------------
# Epoch: 14, Learning Rate: 0.000005
# Batch 0/317 processed, running loss: 0.278169, correct predictions: 16, total: 16
# Batch 70/317 processed, running loss: 27.002266, correct predictions: 1083, total: 1136
# Batch 140/317 processed, running loss: 57.283262, correct predictions: 2143, total: 2256
# Batch 210/317 processed, running loss: 85.492378, correct predictions: 3202, total: 3376
# Batch 280/317 processed, running loss: 114.763299, correct predictions: 4277, total: 4496
#
# Training Loss per batch = 0.410213	Accuracy on Training set = 94.942710% [4806/5062]
#
# Training Loss per batch = 0.410213	Accuracy on Training set = 94.942710% [4806/5062]
#
# Validation Loss per batch = 3.257053	Accuracy on Validation set = 75.488455% [425/563]
# Train Loss: 0.4102, Train Accuracy: 94.9427
# Valid Loss: 3.2571, Valid Accuracy: 75.4885
#
# Validation Loss per batch = 3.257053	Accuracy on Validation set = 75.488455% [425/563]
# Train Loss: 0.4102, Train Accuracy: 94.9427
# Valid Loss: 3.2571, Valid Accuracy: 75.4885
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# <ipython-input-23-a06ff52dd9fb>:72: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'epoch': epoch+1, 'train_loss': train_loss, 'train_accuracy': train_accuracy, 'valid_loss': valid_loss, 'valid_accuracy': valid_accuracy}, ignore_index=True)
# Epoch 16/50
# -------------------------------
# Epoch: 15, Learning Rate: 0.000005
#
# Epoch 16/50
# -------------------------------
# Epoch: 15, Learning Rate: 0.000005
# Batch 0/317 processed, running loss: 0.160068, correct predictions: 16, total: 16
# Batch 0/317 processed, running loss: 0.160068, correct predictions: 16, total: 16
# Batch 70/317 processed, running loss: 25.884671, correct predictions: 1086, total: 1136
# Batch 70/317 processed, running loss: 25.884671, correct predictions: 1086, total: 1136
# Batch 140/317 processed, running loss: 56.698552, correct predictions: 2154, total: 2256
# Batch 140/317 processed, running loss: 56.698552, correct predictions: 2154, total: 2256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-6eaa9dee10ab> in <cell line: 7>()
#       5
#       6 #Call the optimize function.
# ----> 7 train_losses, valid_losses = optimize(train_dataloader,valid_dataloader,model,loss_fn,optimizer,nb_epochs, patience)
#
# <ipython-input-23-a06ff52dd9fb> in optimize(train_dataloader, valid_dataloader, model, loss_fn, optimizer, nb_epochs, patience)
#      34         print('-------------------------------')
#      35         print("Epoch: %d, Learning Rate: %f " % (epoch, optimizer.param_groups[0]['lr']))
# ---> 36         train_loss, train_accuracy = train(train_dataloader,model,loss_fn,optimizer)
#      37         valid_loss, valid_accuracy = validate(valid_dataloader,model,loss_fn)
#      38
#
# <ipython-input-20-8cbaa342b361> in train(dataloader, model, loss_fn, optimizer)
#      21     running_loss = 0
#      22
# ---> 23     for batch,(x,y) in enumerate(dataloader): #Iterates through the batches.
#      24
#      25
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-15-be8482441cd2> in __getitem__(self, index)
#      21             image = self.augment_transform_agg(image)
#      22         if self.train and self.augment_transform and label in self.minority_classes:
# ---> 23             image = self.augment_transform(image)
#      24
#      25         if self.image_transform:
#
# <ipython-input-13-f8d09a7aa396> in __call__(self, img)
#      10     def __call__(self, img):
#      11         if self.rotate:
# ---> 12             img = img.rotate(random.uniform(-25, 25))
#      13         if self.flip_lr and random.random() > 0.5:
#      14             img = F.hflip(img)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in rotate(self, angle, resample, expand, center, translate, fillcolor)
#    2340             w, h = nw, nh
#    2341
# -> 2342         return self.transform(
#    2343             (w, h), Transform.AFFINE, matrix, resample, fillcolor=fillcolor
#    2344         )
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in transform(self, size, method, data, resample, fill, fillcolor)
#    2711                 )
#    2712         else:
# -> 2713             im.__transformer(
#    2714                 (0, 0) + size, self, method, data, resample, fillcolor is None
#    2715             )
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in __transformer(self, box, image, method, data, resample, fill)
#    2794             resample = Resampling.NEAREST
#    2795
# -> 2796         self.im.transform2(box, image.im, method, data, resample, fill)
#    2797
#    2798     def transpose(self, method):
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-6eaa9dee10ab> in <cell line: 7>()
#       5
#       6 #Call the optimize function.
# ----> 7 train_losses, valid_losses = optimize(train_dataloader,valid_dataloader,model,loss_fn,optimizer,nb_epochs, patience)
#
# <ipython-input-23-a06ff52dd9fb> in optimize(train_dataloader, valid_dataloader, model, loss_fn, optimizer, nb_epochs, patience)
#      34         print('-------------------------------')
#      35         print("Epoch: %d, Learning Rate: %f " % (epoch, optimizer.param_groups[0]['lr']))
# ---> 36         train_loss, train_accuracy = train(train_dataloader,model,loss_fn,optimizer)
#      37         valid_loss, valid_accuracy = validate(valid_dataloader,model,loss_fn)
#      38
#
# <ipython-input-20-8cbaa342b361> in train(dataloader, model, loss_fn, optimizer)
#      21     running_loss = 0
#      22
# ---> 23     for batch,(x,y) in enumerate(dataloader): #Iterates through the batches.
#      24
#      25
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-15-be8482441cd2> in __getitem__(self, index)
#      21             image = self.augment_transform_agg(image)
#      22         if self.train and self.augment_transform and label in self.minority_classes:
# ---> 23             image = self.augment_transform(image)
#      24
#      25         if self.image_transform:
#
# <ipython-input-13-f8d09a7aa396> in __call__(self, img)
#      10     def __call__(self, img):
#      11         if self.rotate:
# ---> 12             img = img.rotate(random.uniform(-25, 25))
#      13         if self.flip_lr and random.random() > 0.5:
#      14             img = F.hflip(img)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in rotate(self, angle, resample, expand, center, translate, fillcolor)
#    2340             w, h = nw, nh
#    2341
# -> 2342         return self.transform(
#    2343             (w, h), Transform.AFFINE, matrix, resample, fillcolor=fillcolor
#    2344         )
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in transform(self, size, method, data, resample, fill, fillcolor)
#    2711                 )
#    2712         else:
# -> 2713             im.__transformer(
#    2714                 (0, 0) + size, self, method, data, resample, fillcolor is None
#    2715             )
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in __transformer(self, box, image, method, data, resample, fill)
#    2794             resample = Resampling.NEAREST
#    2795
# -> 2796         self.im.transform2(box, image.im, method, data, resample, fill)
#    2797
#    2798     def transpose(self, method):
#
# KeyboardInterrupt:

# %%
# %cd /content/gdrive/MyDrive/Kaggle/unzip

# %%
model = torch.load("DR_ResNet50_test.pt")
model.eval()  # Set the model to evaluation mode

# Store all the model predictions for the test set
all_preds = []
all_labels = []

# No need to track gradients for evaluation, saves memory and computations
with torch.no_grad():
    for batch in test_dataloader:
        inputs, labels = batch
        inputs = inputs.to(device)
        labels = labels.to(device)
        inputs, labels = inputs.cuda(), labels.cuda() # add this line

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)  # Get the index of the max log-probability

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-89-7a7f9e7709c4> in <cell line: 1>()
# ----> 1 model = torch.load("DR_ResNet50_test.pt")
#       2 model.eval()  # Set the model to evaluation mode
#       3
#       4 # Store all the model predictions for the test set
#       5 all_preds = []
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     984         pickle_load_args['encoding'] = 'utf-8'
#     985
# --> 986     with _open_file_like(f, 'rb') as opened_file:
#     987         if _is_zipfile(opened_file):
#     988             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     433 def _open_file_like(name_or_buffer, mode):
#     434     if _is_path(name_or_buffer):
# --> 435         return _open_file(name_or_buffer, mode)
#     436     else:
#     437         if 'w' in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     414 class _open_file(_opener):
#     415     def __init__(self, name, mode):
# --> 416         super().__init__(open(name, mode))
#     417
#     418     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DR_ResNet50_test.pt'

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()

from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(all_labels, all_preds)
print(classification_report(all_labels, all_preds))

# For multiclass case:
num_classes = cm.shape[0]  # assuming cm is a square matrix

for i in range(num_classes):
    tp = cm[i, i]
    fn = cm[i, :].sum() - tp  # sum across the row, excluding the diagonal element
    fp = cm[:, i].sum() - tp  # sum down the column, excluding the diagonal element
    tn = cm.sum() - fn - fp - tp

    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    print(f"For class {i}, Sensitivity: {sensitivity}, Specificity: {specificity}")

# %%
# !nvidia-smi

# %%
# !pwd

# %%
# !zip -r data.zip test train
